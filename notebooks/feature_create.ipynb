# %% [markdown]
# # This notebook creates additional features from the series details and series data csv files that were created from the get_new_data notebook

# %%
import pandas as pd
import numpy as np
from fred import Fred
import time
import datetime
import csv
import statsmodels.tsa.stattools
from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
# read in the details for all 10868 series
series_dets = pd.read_csv('../data/raw/all_series_details.csv', parse_dates=[4,6,7,9,10], infer_datetime_format=True)

# %%
series_dets
# Out:
#        Unnamed: 0                 frequency frequency_short  \
# 0               0                 Quarterly               Q
# 1               0                 Quarterly               Q
# 2               0                 Quarterly               Q
# 3               0                 Quarterly               Q
# 4               0                 Quarterly               Q
# 5               0                   Monthly               M
# 6               0                   Monthly               M
# 7               0                   Monthly               M
# 8               0                   Monthly               M
# 9               0                 Quarterly               Q
# 10              0                   Monthly               M
# 11              0                   Monthly               M
# 12              0                 Quarterly               Q
# 13              0                 Quarterly               Q
# 14              0                 Quarterly               Q
# 15              0                 Quarterly               Q
# 16              0                 Quarterly               Q
# 17              0                   Monthly               M
# 18              0                   Monthly               M
# 19              0                 Quarterly               Q
# 20              0                 Quarterly               Q
# 21              0                   Monthly               M
# 22              0                 Quarterly               Q
# 23              0                 Quarterly               Q
# 24              0                   Monthly               M
# 25              0                   Monthly               M
# 26              0                 Quarterly               Q
# 27              0                   Monthly               M
# 28              0                   Monthly               M
# 29              0                 Quarterly               Q
# ...           ...                       ...             ...
# 10838           0                 Quarterly               Q
# 10839           0                 Quarterly               Q
# 10840           0                   Monthly               M
# 10841           0  Quarterly, End of Period               Q
# 10842           0                 Quarterly               Q
# 10843           0                   Monthly               M
# 10844           0                   Monthly               M
# 10845           0                   Monthly               M
# 10846           0                   Monthly               M
# 10847           0                 Quarterly               Q
# 10848           0                 Quarterly               Q
# 10849           0                 Quarterly               Q
# 10850           0                 Quarterly               Q
# 10851           0                   Monthly               M
# 10852           0                 Quarterly               Q
# 10853           0                   Monthly               M
# 10854           0                 Quarterly               Q
# 10855           0                 Quarterly               Q
# 10856           0                   Monthly               M
# 10857           0                 Quarterly               Q
# 10858           0                 Quarterly               Q
# 10859           0                 Quarterly               Q
# 10860           0                   Monthly               M
# 10861           0                   Monthly               M
# 10862           0                 Quarterly               Q
# 10863           0                 Quarterly               Q
# 10864           0                 Quarterly               Q
# 10865           0              Daily, 7-Day               D
# 10866           0                 Quarterly               Q
# 10867           0                   Monthly               M
#
#                        id        last_updated  \
# 0         XTEXVA01DKQ667S 2019-08-12 20:08:35
# 1         B139RL1Q225SBEA 2019-08-29 12:59:46
# 2             NNBTFAQ027S 2019-06-06 16:31:42
# 3         W108RC1Q027SBEA 2019-08-29 13:03:05
# 4          CAPUTLHITEK2SQ 2019-08-15 13:27:13
# 5             FEDMINNFRWG 2019-08-30 19:01:01
# 6      NOCDFNA066MNFRBPHI 2019-08-15 12:46:12
# 7             WPUSI093011 2019-08-09 12:51:23
# 8             CAPUTLG325S 2019-08-15 13:27:06
# 9          JPNPISPIG01GPQ 2019-08-12 17:00:02
# 10         USAPITGCD01GPM 2019-08-12 16:58:53
# 1      BEA Account Code: B139RL\r\n\r\nFor more infor...      2019-04-01
# 2      Source ID: FA114090005.Q\r\n\r\nFor more infor...      2019-01-01
# 3      BEA Account Code: W108RC\r\n\r\nFor more infor...      2019-04-01
# 4      For a given industry, the capacity utilization...      2019-04-01
# 5      The federal minimum wage is the minimum hourly...      2019-08-01
# 6      Current New Orders reports the change in new o...      2019-08-01
# 7                                                    NaN      2019-07-01
# 8      For a given industry, the capacity utilization...      2019-07-01
# 9      OECD descriptor ID: PISPIG01 OECD unit ID: GP ...      2019-04-01
# 10     OECD descriptor ID: USA.PITGCD01.GP.M OECD uni...      2019-06-01
# 11     Production and related employees include worki...      2019-07-01
# 12     OECD descriptor ID: PISPFG01\r\nOECD unit ID: ...      2019-04-01
# 13     BEA Account Code: B008RG\r\n\r\nFor more infor...      2019-04-01
# 14     BEA Account Code: DREQRV\r\n\r\nFor more infor...      2019-04-01
# 15     OECD descriptor ID: TUR.CP010000.IXNB.Q OECD u...      2019-04-01
# 16     Source ID: FL152100005.Q\r\n\r\nFor more infor...      2019-01-01
# 17     OECD descriptor ID: XTNTVA01\r\nOECD unit ID: ...      2019-06-01
# 18     The diffusion indexes are calculated as the pe...      2019-06-01
# 19     OECD descriptor ID: LFHUADTT\r\nOECD unit ID: ...      2019-01-01
# 20     OECD descriptor ID: PRCNTO01\r\nOECD unit ID: ...      2019-01-01
# 21     OECD descriptor ID: LORSGPNO OECD unit ID: STS...      2019-03-01
# 22     OECD descriptor ID: XTEXVA01\r\nOECD unit ID: ...      2019-04-01
# 23     BEA Account Code: B394RC\r\n\r\nFor more infor...      2019-04-01
# 24     Further information and definitions are availa...      2019-07-01
# 25                                                   NaN      2019-07-01
# 26     OECD descriptor ID: PRMNTO01\r\nOECD unit ID: ...      2019-01-01
# 27                                                   NaN      2019-07-01
# 28     OECD descriptor ID: LRHUADFE\r\nOECD unit ID: ...      2019-07-01
# 29     Source ID: FA153076005.Q\r\n\r\nFor more infor...      2019-01-01
# ...                                                  ...             ...
# 10838  Copyright, 2016, OECD. Reprinted with permissi...      2019-01-01
# 10839  BEA Account Code: B247RC\r\n\r\nFor more infor...      2019-04-01
# 10840  Notes regarding this series can be found in In...      2019-07-01
# 10841  Source ID: FL102090005.Q\r\n\r\nFor more infor...      2019-01-01
# 10842  OECD descriptor ID: LFHU24FE\r\nOECD unit ID: ...      2019-01-01
# 10843                                                NaN      2019-07-01
# 10844  To obtain estimates of women worker employment...      2019-07-01
# 10845  This time series is an interpretation of Organ...      2019-04-01
# 10846  OECD descriptor ID: XTEXVA01\r\nOECD unit ID: ...      2019-06-01
# 10847  BEA Account Code: B696RG\r\n\r\nFor more infor...      2019-04-01
# 10848  BEA Account Code: DTRSRA\r\n\r\nFor more infor...      2019-04-01
# 10849  OECD descriptor ID: CP040500 OECD unit ID: GP ...      2019-01-01
# 10850  Source ID: FL213162200.Q\r\n\r\nFor more infor...      2019-01-01
# 10851                                                NaN      2019-07-01
# 10852  BEA Account Code: W106RC\r\n\r\nFor more infor...      2019-04-01
# 10853  Nominal effective exchange rates are calculate...      2019-07-01
# 10854  OECD descriptor ID: BSOITE02\r\nOECD unit ID: ...      2019-07-01
# 10855  OECD descriptor ID: XTIMVA01\r\nOECD unit ID: ...      2019-04-01
# 10856                                                NaN      2019-07-01
# 10857  BEA Account Code: DOTSRC\r\n\r\nFor more infor...      2019-04-01
# 10858  This series appears in Table 14c.\r\nSource Co...      2019-01-01
# 10859  OECD descriptor ID: PITGCD01 OECD unit ID: GP ...      2019-04-01
# 10860  OECD descriptor ID: PIEAMP02\r\nOECD unit ID: ...      2019-06-01
# 10861  OECD descriptor ID: MANMM101\r\nOECD unit ID: ...      2019-06-01
# 10862  OECD descriptor ID: LRUNTTMA\r\nOECD unit ID: ...      2019-01-01
# 10863  BEA Account Code: W085RA\r\n\r\nFor more infor...      2019-04-01
# 10864  This series appears in Table 11d.\r\nSource Co...      2019-01-01
# 10865  This time series is an interpretation of Organ...      2019-06-30
# 10866                                                NaN      2019-04-01
# 10867  To obtain estimates of women worker employment...      2019-07-01
#
#       observation_start  popularity realtime_end realtime_start  \
# 0            1960-01-01           1   2019-08-31     2019-08-31
# 1            1947-04-01           1   2019-08-31     2019-08-31
# 2            1946-10-01           1   2019-08-31     2019-08-31
# 3            1947-01-01           0   2019-08-31     2019-08-31
# 4            1967-01-01          11   2019-08-31     2019-08-31
# 5            1938-10-01          40   2019-08-31     2019-08-31
# 6            1968-05-01           2   2019-08-31     2019-08-31
# 7            1967-01-01           1   2019-08-31     2019-08-31
# 8            1948-01-01          13   2019-08-31     2019-08-31
# 9            1960-04-01           0   2019-08-31     2019-08-31
# 10           1960-01-01           0   2019-08-31     2019-08-31
# 11           1964-01-01          16   2019-08-31     2019-08-31
# 12           1960-01-01           1   2019-08-31     2019-08-31
# 13           1947-01-01           2   2019-08-31     2019-08-31
# 14           1947-04-01           1   2019-08-31     2019-08-31
# 15           1963-01-01           0   2019-08-31     2019-08-31
# 16           1945-10-01           3   2019-08-31     2019-08-31
# 17           1960-01-01           1   2019-08-31     2019-08-31
# 18           1967-01-01           3   2019-08-31     2019-08-31
# 19           1960-01-01           0   2019-08-31     2019-08-31
# 20           1960-01-01           1   2019-08-31     2019-08-31
# 21           1960-02-01           3   2019-08-31     2019-08-31
# 22           1960-01-01           1   2019-08-31     2019-08-31
# 23           1948-01-01          10   2019-08-31     2019-08-31
# 24           1959-01-01           1   2019-08-31     2019-08-31
# 25           1966-11-01           1   2019-08-31     2019-08-31
# 26           1960-01-01           1   2019-08-31     2019-08-31
# 27           1967-01-01           1   2019-08-31     2019-08-31
# 28           1960-01-01           1   2019-08-31     2019-08-31
# 29           1946-10-01           1   2019-08-31     2019-08-31
# ...                 ...         ...          ...            ...
# 10838        1960-01-01           1   2019-08-31     2019-08-31
# 10839        1958-01-01           1   2019-08-31     2019-08-31
# 10840        1957-01-01          15   2019-08-31     2019-08-31
# 10841        1945-10-01          31   2019-08-31     2019-08-31
# 10842        1960-01-01           0   2019-08-31     2019-08-31
# 10843        1926-01-01           1   2019-08-31     2019-08-31
# 10844        1948-01-01           1   2019-08-31     2019-08-31
# 10845        1960-02-01           1   2019-08-31     2019-08-31
# 10846        1960-01-01           1   2019-08-31     2019-08-31
# 10847        1967-01-01           3   2019-08-31     2019-08-31
# 10848        1959-01-01           1   2019-08-31     2019-08-31
# 10849        1960-01-01           0   2019-08-31     2019-08-31
# 10850        1945-10-01           1   2019-08-31     2019-08-31
# 10851        1956-01-01          16   2019-08-31     2019-08-31
# 10852        1947-01-01           1   2019-08-31     2019-08-31
# 10853        1964-01-01           2   2019-08-31     2019-08-31
# 10854        1961-01-01           1   2019-08-31     2019-08-31
# 10855        1960-01-01           1   2019-08-31     2019-08-31
# 10856        1939-01-01          25   2019-08-31     2019-08-31
# 10857        1959-01-01           1   2019-08-31     2019-08-31
# 10858        1966-04-01           1   2019-08-31     2019-08-31
# 10859        1960-04-01           0   2019-08-31     2019-08-31
# 10860        1960-01-01           5   2019-08-31     2019-08-31
# 10861        1960-01-01          16   2019-08-31     2019-08-31
# 10862        1960-01-01           1   2019-08-31     2019-08-31
# 10863        1947-01-01           1   2019-08-31     2019-08-31
# 10864        1966-01-01           1   2019-08-31     2019-08-31
# 10865        1960-02-01           1   2019-08-31     2019-08-31
# 10866        1947-01-01          10   2019-08-31     2019-08-31
# 10867        1948-01-01          53   2019-08-31     2019-08-31
#
#                    seasonal_adjustment seasonal_adjustment_short  \
# 0                  Seasonally Adjusted                        SA
# 1      Seasonally Adjusted Annual Rate                      SAAR
# 2      Seasonally Adjusted Annual Rate                      SAAR
# 3      Seasonally Adjusted Annual Rate                      SAAR
# 4                  Seasonally Adjusted                        SA
# 5              Not Seasonally Adjusted                       NSA
# 6              Not Seasonally Adjusted                       NSA
# 7              Not Seasonally Adjusted                       NSA
# 8                  Seasonally Adjusted                        SA
# 9              Not Seasonally Adjusted                       NSA
# 10             Not Seasonally adjusted   Not Seasonally adjusted
# 11                 Seasonally Adjusted                        SA
# 12             Not Seasonally Adjusted                       NSA
# 13                 Seasonally Adjusted                        SA
# 14     Seasonally Adjusted Annual Rate                      SAAR
# 15             Not Seasonally adjusted   Not Seasonally adjusted
# 16             Not Seasonally Adjusted                       NSA
# 17             Not Seasonally Adjusted                       NSA
# 18             Not Seasonally Adjusted                       NSA
# 19             Not Seasonally Adjusted                       NSA
# 20                 Seasonally Adjusted                        SA
# 21                 Seasonally Adjusted                        SA
# 22             Not Seasonally Adjusted                       NSA
# 23     Seasonally Adjusted Annual Rate                      SAAR
# 24                 Seasonally Adjusted                        SA
# 25             Not Seasonally Adjusted                       NSA
# 26             Not Seasonally Adjusted                       NSA
# 27                 Seasonally Adjusted                        SA
# 28                 Seasonally Adjusted                        SA
# 29                 Seasonally Adjusted                        SA
# ...                                ...                       ...
# 10838          Not Seasonally Adjusted                       NSA
# 10839  Seasonally Adjusted Annual Rate                      SAAR
# 10840          Not Seasonally Adjusted                       NSA
# 10841          Not Seasonally Adjusted                       NSA
# 10842          Not Seasonally Adjusted                       NSA
# 10843          Not Seasonally Adjusted                       NSA
# 10844          Not Seasonally Adjusted                       NSA
# 10845          Not Seasonally Adjusted                       NSA
# 10846              Seasonally Adjusted                        SA
# 10847              Seasonally Adjusted                        SA
# 10848              Seasonally Adjusted                        SA
# 10849          Not Seasonally Adjusted                       NSA
# 10850          Not Seasonally Adjusted                       NSA
# 10851              Seasonally Adjusted                        SA
# 10852  Seasonally Adjusted Annual Rate                      SAAR
# 10853          Not Seasonally Adjusted                       NSA
# 10854              Seasonally Adjusted                        SA
# 10855              Seasonally Adjusted                        SA
# 10856              Seasonally Adjusted                        SA
# 10857  Seasonally Adjusted Annual Rate                      SAAR
# 10858          Not Seasonally Adjusted                       NSA
# 10859          Not Seasonally Adjusted                       NSA
# 10860          Not Seasonally Adjusted                       NSA
# 10861              Seasonally Adjusted                        SA
# 10862              Seasonally Adjusted                        SA
# 10863              Seasonally Adjusted                        SA
# 10864          Not Seasonally Adjusted                       NSA
# 10865          Not Seasonally Adjusted                       NSA
# 10866              Seasonally Adjusted                        SA
# 10867              Seasonally Adjusted                        SA
#
#                                                    title  \
# 0                       Exports: Value Goods for Denmark
# 1      Real Motor Vehicle Output: Final Sales of Dome...
# 2      Nonfinancial noncorporate business; total fina...
# 3      Government consumption expenditures: Own-accou...
# 4      Capacity Utilization: Computers, communication...
# 5      Federal Minimum Hourly Wage for Nonfarm Worker...
# 6      Current New Orders; Diffusion Index for FRB - ...
# 7      Producer Price Index by Commodity for Special ...
# 8      Capacity Utilization: Nondurable Manufacturing...
# 9      Producer Prices Index: Stage of processing: In...
# 10     Producer Prices Index: Type of goods: Durable ...
# 11     Average Weekly Earnings of Production and Nons...
# 12     Producer Prices Index: Stage of Processing: To...
# 13     Real private fixed investment: Nonresidential ...
# 14     Personal Consumption Expenditures: Goods: Dura...
# 15     Consumer Price Index: Food and non-Alcoholic b...
# 16     Households and nonprofit organizations; total ...
# 17                Net Trade: Value Goods for Switzerland
# 18     Industrial Production: Diffusion Indexes: Six ...
# 19     Harmonized Unemployment: Aged 25 and Over: All...
# 20             Total Construction for the United Kingdom
# 21     Leading Indicators OECD: Reference series: Gro...
# 22                 Exports: Value Goods for South Africa
# 23     Corporate profits with inventory valuation and...
# 24            Small Time Deposits at Thrift Institutions
# 25     Consumer Price Index for All Urban Consumers: ...
# 26            Total Manufacturing Production for Austria
# 27     Producer Price Index by Commodity for Intermed...
# 28     Harmonized Unemployment: Aged 25 and Over: Fem...
# 29     Households and nonprofit organizations; insura...
# ...                                                  ...
# 10838       Consumer Price Index: Energy for Netherlands
# 10839  State and local government current tax receipt...
# 10840  Interest Rates, Government Securities, Treasur...
# 10841  Nonfinancial corporate business; net worth, Level
# 10842  Harmonized Unemployment: Aged 15-24: Females f...
# 10843  Producer Price Index by Commodity for Metals a...
# 10844         Employment Level: 55 years and over, Women
# 10845  OECD based Recession Indicators for Australia ...
# 10846                    Exports: Value Goods for Canada
# 10847  Imports of goods: Industrial supplies and mate...
# 10848  Real personal consumption expenditures: Transp...
# 10849  Consumer Price Index: Housing, water, electric...
# 10850  State and local governments, excluding employe...
# 10851  Consumer Price Index for All Urban Consumers: ...
# 10852  Government consumption expenditures: Gross out...
# 10853          Narrow Effective Exchange Rate for France
# 10854  Business Tendency Surveys for Manufacturing: O...
# 10855               Imports: Value Goods for Switzerland
# 10856  Industrial Production: Electric and Gas Utilities
# 10857  Personal consumption expenditures: Other services
# 10858  Amount Outstanding Due within One Year of Inte...
# 10859  Producer Prices Index: Type of goods: Durable ...
# 10860  Producer Prices Index: Economic Activities: Do...
# 10861                                       M1 for Japan
# 10862  Unemployment Rate: Aged 15 and Over: Males for...
# 10863  Real federal government consumption expenditur...
# 10864  Amount Outstanding of International Debt Secur...
# 10865  OECD based Recession Indicators for France fro...
# 10866   Nonfarm Business Sector: Implicit Price Deflator
# 10867     Civilian Labor Force Participation Rate: Women
#
#                                        units  \
# 0                   US Dollars Monthly Level
# 1       Percent Change from Preceding Period
# 2                        Millions of Dollars
# 3                        Billions of Dollars
# 4                        Percent of Capacity
# 5                           Dollars per Hour
# 6                                      Index
# 7                             Index 1982=100
# 8                        Percent of Capacity
# 9                Growth rate previous period
# 10               Growth rate previous period
# 11                          Dollars per Week
# 12                            Index 2015=100
# 13                            Index 2012=100
# 14      Percent Change from Preceding Period
# 15                         Index source base
# 16                       Millions of Dollars
# 17          National currency, Monthly Level
# 18                                   Percent
# 19                                   Persons
# 20               Growth Rate Previous Period
# 21                                     Index
# 22          National currency, Monthly Level
# 23                       Billions of Dollars
# 24                       Billions of Dollars
# 25                       Index 1982-1984=100
# 26                            Index 2015=100
# 27                            Index 1982=100
# 28                                   Percent
# 29                       Millions of Dollars
# ...                                      ...
# 10838                         Index 2015=100
# 10839                    Billions of Dollars
# 10840                      Percent per Annum
# 10841                    Billions of Dollars
# 10842                                Persons
# 10843                         Index 1982=100
# 10844                   Thousands of Persons
# 10845                                +1 or 0
# 10846  Growth Rate Same Period Previous Year
# 10847                         Index 2012=100
# 10848                         Index 2012=100
# 10849            Growth rate previous period
# 10850                    Millions of Dollars
# 10851                    Index 1982-1984=100
# 10852                    Billions of Dollars
# 10853                         Index 2010=100
# 10854                            Net Percent
# 10855               US Dollars Monthly Level
# 10856                         Index 2012=100
# 10857                    Billions of Dollars
# 10858                 Millions of US Dollars
# 10859            Growth rate previous period
# 10860  Growth Rate Same Period Previous Year
# 10861                      National Currency
# 10862                                Percent
# 10863                         Index 2012=100
# 10864                 Millions of US Dollars
# 10865                                +1 or 0
# 10866                         Index 2012=100
# 10867                                Percent
#
#                                 units_short
# 0                       US $, Monthly Level
# 1              % Chg. from Preceding Period
# 2                                 Mil. of $
# 3                                 Bil. of $
# 4                             % of Capacity
# 5                                $ per Hour
# 6                                     Index
# 7                            Index 1982=100
# 8                             % of Capacity
# 9               Growth rate previous period
# 10              Growth rate previous period
# 11                               $ per Week
# 12                           Index 2015=100
# 13                           Index 2012=100
# 14             % Chg. from Preceding Period
# 15                        Index source base
# 16                                Mil. of $
# 17         National currency, Monthly Level
# 18                                        %
# 19                                  Persons
# 20              Growth Rate Previous Period
# 21                                    Index
# 22         National currency, Monthly Level
# 23                                Bil. of $
# 24                                Bil. of $
# 25                      Index 1982-1984=100
# 26                           Index 2015=100
# 27                           Index 1982=100
# 28                                        %
# 29                                Mil. of $
# ...                                     ...
# 10838                        Index 2015=100
# 10839                             Bil. of $
# 10840                           % per Annum
# 10841                             Bil. of $
# 10842                               Persons
# 10843                        Index 1982=100
# 10844                     Thous. of Persons
# 10845                               +1 or 0
# 10846  Growth Rate Same Period Previous Yr.
# 10847                        Index 2012=100
# 10848                        Index 2012=100
# 10849           Growth rate previous period
# 10850                             Mil. of $
# 10851                     Index 1982-84=100
# 10852                             Bil. of $
# 10853                        Index 2010=100
# 10854                                 Net %
# 10855                   US $, Monthly Level
# 10856                        Index 2012=100
# 10857                             Bil. of $
# 10858                          Mil. of US $
# 10859           Growth rate previous period
# 10860  Growth Rate Same Period Previous Yr.
# 10861                     National Currency
# 10862                                     %
# 10863                        Index 2012=100
# 10864                          Mil. of US $
# 10865                               +1 or 0
# 10866                        Index 2012=100
# 10867                                     %
#
# [10868 rows x 16 columns]

# %% [markdown]
# Do not create percentage difference features for series that are already 'growth' series or 'change' series or series that are chained to a specific year.

# %%
ser_perc = series_dets[series_dets.units.str.contains('Percent', case=False)].id.values
ser_grow = series_dets[series_dets.units.str.contains('growth', case=False)].id.values
ser_chg = series_dets[series_dets.units.str.contains('change', case=False)].id.values

# %%
ser_idx = series_dets[series_dets.units.str.contains('index', case=False)].id.values
ser_chn = series_dets[series_dets.units.str.contains('chain', case=False)].id.values
ser_chn2 = series_dets[series_dets.title.str.contains('chain', case=False)].id.values
ser_chg2 = series_dets[series_dets.title.str.contains('change', case=False)].id.values

# %%
ser_pgc = set(list(ser_grow) + list(ser_chg) +list(ser_chn) +list(ser_chn2)+list(ser_chg2))

# %%
len(ser_pgc)
# Out:
# 3050

# %%
ser_data = pd.read_csv('../data/processed/all_series_data-082919.csv', index_col='date')
sdf = pd.read_csv('../data/processed/sp500_rsales.csv', index_col='date')

# add data for sp500 and retail sales
ser_data = pd.concat([ser_data, sdf], axis=1, sort=False)

# drop series that are all zeros
zero_drop = list(ser_data.sum()[ser_data.sum() == 0].index)
ser_data.drop(zero_drop, axis=1, inplace=True)

# drop this seris beacause it is problematic
ser_data.drop('A191RE1Q156NBEA', axis=1, inplace=True)
ser_data.shape
# Out:
# (619, 10863)

# %%
ser_data.isna().sum().sum()
# Out:
# 0

# %%
# scale data first to 0-1
rec_ser = ser_data.RECESSION.values
ser_data.drop('RECESSION', axis=1, inplace=True)
ser_data = (ser_data - ser_data.min()) / (ser_data.max() - ser_data.min())
ser_data.head()
# Out:
#             LRHUTTMAJPM156S  CANLOLITOAASTSAM  MANMM101ISM657S  DDDFOINS  \
# date
# 1968-01-01         0.061224          0.624295         0.247070  0.011869
# 1968-02-01         0.061224          0.620568         0.291203  0.008902
# 1968-03-01         0.040816          0.620005         0.241940  0.011869
# 1968-04-01         0.061224          0.625887         0.313992  0.011869
# 1968-05-01         0.020408          0.637924         0.610442  0.011869
#
#             CES4000000007  PCU333618333618F  IDS1YMAORIAIIS   WPU0284  \
# date
# 1968-01-01       1.000000          0.000000             0.0  0.000000
# 1968-02-01       1.000000          0.001170             0.0  0.001451
# 1968-03-01       1.000000          0.001170             0.0  0.001451
# 1968-04-01       1.000000          0.001170             0.0  0.001451
# 1968-05-01       0.982143          0.002341             0.0  0.001451
#
#             IRSTCI01SEQ156N  CUURA318SAM    ...     NAEXKP07USQ652S  \
# date                                        ...
# 1968-01-01         0.475806     0.000000    ...            0.002108
# 1968-02-01         0.475806     0.000000    ...            0.002108
# 1968-03-01         0.475806     0.000000    ...            0.002108
# 1968-04-01         0.475806     0.000206    ...            0.002108
# 1968-05-01         0.475806     0.000206    ...            0.002108
#
#             MABMM301INM189N  XTNTVA01GRM664N  LFWA25FEUSM647N  \
# date
# 1968-01-01         0.000000         0.999988         0.000000
# 1968-02-01         0.000005         0.999916         0.001152
# 1968-03-01         0.000014         0.999954         0.002304
# 1968-04-01         0.000024         0.999980         0.003456
# 1968-05-01         0.000023         0.999164         0.004643
#
#             AB67RG3Q086SBEA  PRS88003142  LNS13000319  ULQEUL01FRQ657S  \
# date
# 1968-01-01              0.0     0.451613     0.111940          0.53032
# 1968-02-01              0.0     0.451613     0.171642          0.53032
# 1968-03-01              0.0     0.451613     0.196517          0.53032
# 1968-04-01              0.0     0.451613     0.233831          0.53032
# 1968-05-01              0.0     0.451613     0.236318          0.53032
#
#                SP500     RRSFS
# date
# 1968-01-01  0.009839  0.000000
# 1968-02-01  0.008852  0.005216
# 1968-03-01  0.009140  0.017762
# 1968-04-01  0.011629  0.014621
# 1968-05-01  0.012047  0.016720
#
# [5 rows x 10862 columns]

# %%
ser_data.isna().sum().sum()
# Out:
# 0

# %%
rec_ser = rec_ser[12:]

# add columns for difference from a quarter ago, a year ago, and from the 10month moving average
for col in ser_data.columns:
    if col not in ser_pgc:
        ser_data[col + '_diffQ'] = (ser_data[col] - ser_data[col].shift(3)) / ser_data[col].shift(3)
        ser_data[col + '_diffA'] = (ser_data[col] - ser_data[col].shift(12)) / ser_data[col].shift(12)
        ser_data[col + '_diffMA'] = (ser_data[col] - ser_data[col].rolling(10).mean()) / ser_data[col].rolling(10).mean()
    
# start the data at 1/1/69
# previous data for the new features above
ser_data = ser_data.iloc[12:]

# make sure no NAs in the data
print('nan ',ser_data.isna().sum().sum())
print('inf ',np.isinf(ser_data.values).sum())
# Out:
# nan  264463
# inf  66369

# %%
# first replace inf with nan
ser_data.replace([np.inf, -np.inf], np.nan, inplace=True)

# fill nan with zeros
ser_data.fillna(0, inplace=True)
print('nan ',ser_data.isna().sum().sum())
print('inf ',np.isinf(ser_data.values).sum())
# Out:
# nan  0
# inf  0

# %%
ser_data['RECESSION'] = rec_ser
ser_data.index = pd.to_datetime(ser_data.index)
ser_data.head()
# Out:
#             LRHUTTMAJPM156S  CANLOLITOAASTSAM  MANMM101ISM657S  DDDFOINS  \
# date
# 1969-01-01         0.020408          0.810435         0.718261  0.011869
# 1969-02-01         0.040816          0.809665         0.502998  0.008902
# 1969-03-01         0.040816          0.797792         0.599633  0.008902
# 1969-04-01         0.040816          0.775092         0.580753  0.008902
# 1969-05-01         0.061224          0.743442         0.554535  0.008902
#
#             CES4000000007  PCU333618333618F  IDS1YMAORIAIIS   WPU0284  \
# date
# 1969-01-01       0.982143          0.009947             0.0  0.011611
# 1969-02-01       0.946429          0.010532             0.0  0.011611
# 1969-03-01       0.946429          0.010532             0.0  0.011611
# 1969-04-01       0.928571          0.010532             0.0  0.011611
# 1969-05-01       0.946429          0.011703             0.0  0.009192
#
#             IRSTCI01SEQ156N  CUURA318SAM    ...      LNS13000319_diffQ  \
# date                                        ...
# 1969-01-01         0.435484     0.003921    ...              -0.179104
# 1969-02-01         0.435484     0.003921    ...              -0.098765
# 1969-03-01         0.516129     0.003921    ...               0.030303
# 1969-04-01         0.516129     0.005366    ...               0.109091
# 1969-05-01         0.516129     0.005366    ...               0.410959
#
#             LNS13000319_diffA  LNS13000319_diffMA  SP500_diffQ  SP500_diffA  \
# date
# 1969-01-01           0.222222           -0.307305    -0.010033     0.375262
# 1969-02-01           0.057971           -0.055627    -0.228419     0.339659
# 1969-03-01          -0.139241           -0.088472    -0.058284     0.424231
# 1969-04-01          -0.351064           -0.151599     0.017228     0.183668
# 1969-05-01           0.084211            0.418733     0.154091     0.136027
#
#             SP500_diffMA  RRSFS_diffQ  RRSFS_diffA  RRSFS_diffMA  RECESSION
# date
# 1969-01-01      0.043517     0.183119     0.000000      0.343247          0
# 1969-02-01     -0.087118    -0.107380     6.804769      0.320108          0
# 1969-03-01     -0.005344    -0.076143     0.715098     -0.054273          0
# 1969-04-01      0.040560    -0.193317     1.091972     -0.072000          0
# 1969-05-01      0.019486    -0.145121     1.081358      0.032090          0
#
# [5 rows x 34299 columns]

# %%
# replace values of greater than 10 (1000 percent change), with nan
ser_data.where(ser_data <= 10, np.nan, inplace=True)

# %%
# fill with most recent reasonable value
ser_data.fillna(method='ffill', inplace=True)

# %%
# if no recent data, then fill with zero
ser_data.fillna(0, inplace=True)

# %%
# limit the rest of the difference data to a 100 percent change
ser_data.clip_upper(1, inplace=True)

# %%
ser_data.max()[ser_data.max() > .9].sort_values()
# Out:
# ESPCPIALLMINMEI_diffQ       0.900000
# CUURA318SAM_diffQ           0.900000
# CUURA318SAS_diffQ           0.900000
# PCU339930339930_diffQ       0.900000
# CUURA319SACL1_diffQ         0.900000
# LFEAAGTTUSQ647S             0.900385
# IPB51210N_diffMA            0.901774
# B092RC1Q027SBEA_diffMA      0.901830
# ZAFB6DBSE01NCCUQ_diffMA     0.901840
# NORPROMANMISMEI_diffMA      0.901840
# A681RC1Q027SBEA_diffMA      0.901840
# ZAFB6DBSE01CXCUQ_diffMA     0.901840
# WPU0161_diffMA              0.901944
# PCU335911335911_diffMA      0.902174
# PDIVCA_diffMA               0.902277
# USDIVCA_diffMA              0.902277
# LRAC64MAJPM156N_diffMA      0.902289
# XTIMVA01GBM664S_diffMA      0.902314
# VALIMPGBM052N_diffMA        0.902314
# XTIMVA01GBM664N_diffMA      0.902314
# FINXTIMVA01CXMLM_diffMA     0.902576
# XTIMVA01CAQ188S_diffMA      0.902655
# WPU0382_diffMA              0.902937
# CAPUTLG316SQ                0.903307
# LFWA24TTUSM647N_diffMA      0.903480
# LRAC55FEJPQ156N_diffMA      0.903606
# LRAC55FEJPM156N_diffMA      0.903758
# UOFINA156MNFRBPHI_diffMA    0.903766
# NLDXTIMVA01CXMLM_diffMA     0.903941
# LFACTTTTCAQ647N_diffA       0.904225
#                               ...
# E318RG3Q086SBEA             1.000000
# USAPRCNTO01GYSAM            1.000000
# LFUNTTTTUSM647N             1.000000
# SHFDNA156MNFRBPHI           1.000000
# INVCQRMTSPL                 1.000000
# DNKREC                      1.000000
# CUURA207SACL1               1.000000
# A643RZ2Q224SBEA             1.000000
# IRLRECP                     1.000000
# JPNSLRTCR03MLM              1.000000
# ASTIWEQ027S                 1.000000
# B292RA3Q086SBEA             1.000000
# NORGDPDEFQISMEI             1.000000
# CPALTT01PTQ659N             1.000000
# A756RC1Q027SBEA             1.000000
# FLREVOLSLA                  1.000000
# CAPG331SQ                   1.000000
# CFNAI                       1.000000
# IPB52200NQ                  1.000000
# WPU1241                     1.000000
# LFAC25TTJPM647N             1.000000
# WPU071102                   1.000000
# ULQECU01FRQ661S             1.000000
# B643RA3Q086SBEA             1.000000
# NAEXKP02FRQ661S             1.000000
# FGCEAPQ027S                 1.000000
# CEU8000000008               1.000000
# CCUSSP02BRM650N             1.000000
# Y053RA3Q086SBEA             1.000000
# RECESSION                   1.000000
# Length: 29309, dtype: float64

# %%
ser_data.shape
# Out:
# (607, 34299)

# %%
# dates to drop from rows that are part of reccesion but not within 3 months of the start
dates = list(pd.date_range(start='1970-03-01', end='1970-09-01', freq='MS'))\
      + list(pd.date_range(start='1974-02-01', end='1975-02-01', freq='MS'))\
      + list(pd.date_range(start='1980-04-01', end='1980-06-01', freq='MS'))\
      + list(pd.date_range(start='1981-10-01', end='1982-10-01', freq='MS'))\
      + list(pd.date_range(start='1990-10-01', end='1991-02-01', freq='MS'))\
      + list(pd.date_range(start='2001-06-01', end='2001-10-01', freq='MS'))\
      + list(pd.date_range(start='2008-03-01', end='2009-05-01', freq='MS'))

ser_data2 = ser_data.drop(dates)
rec_df = ser_data2['RECESSION']

# %%
# complete dataset before any drops
ser_data2.to_csv('../data/processed/series_data_scaled2-082919.csv')

# %%
# non-stationary data
def non_stat(series):
    result = adfuller(series)
    if result[0] > result[4]['10%']:
        return True
    else:
        return False

# %%
nstat = ser_data2.apply(non_stat)

# %%
stat_drop = list(nstat[nstat].index)
len(stat_drop)
# Out:
# 7979

# %%
# this is slower, do not use this
stat_drop=[]
for col in ser_data2.columns:
    result = adfuller(ser_data2[col])
    if result[0] > result[4]['10%']:
        stat_drop.append(col)
len(stat_drop)
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-157-6d6cb0d7cda7> in <module>
#       1 stat_drop=[]
#       2 for col, ser in ser_data2.iteritems():
# ----> 3     result = adfuller(ser)
#       4     if result[0] > result[4]['10%']:
#       5         stat_drop.append(col)
#
# ~\Anaconda3\envs\recession\lib\site-packages\statsmodels\tsa\stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     239         if not regresults:
#     240             icbest, bestlag = _autolag(OLS, xdshort, fullRHS, startlag,
# --> 241                                        maxlag, autolag)
#     242         else:
#     243             icbest, bestlag, alres = _autolag(OLS, xdshort, fullRHS, startlag,
#
# ~\Anaconda3\envs\recession\lib\site-packages\statsmodels\tsa\stattools.py in _autolag(mod, endog, exog, startlag, maxlag, method, modargs, fitargs, regresults)
#      84     method = method.lower()
#      85     for lag in range(startlag, startlag + maxlag + 1):
# ---> 86         mod_instance = mod(endog, exog[:, :lag], *modargs)
#      87         results[lag] = mod_instance.fit()
#      88
#
# ~\Anaconda3\envs\recession\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     815                  **kwargs):
#     816         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 817                                   hasconst=hasconst, **kwargs)
#     818         if "weights" in self._init_keys:
#     819             self._init_keys.remove("weights")
#
# ~\Anaconda3\envs\recession\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     661             weights = weights.squeeze()
#     662         super(WLS, self).__init__(endog, exog, missing=missing,
# --> 663                                   weights=weights, hasconst=hasconst, **kwargs)
#     664         nobs = self.exog.shape[0]
#     665         weights = self.weights
#
# ~\Anaconda3\envs\recession\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, **kwargs)
#     177     """
#     178     def __init__(self, endog, exog, **kwargs):
# --> 179         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     180         self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#     181
#
# ~\Anaconda3\envs\recession\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#     210
#     211     def __init__(self, endog, exog=None, **kwargs):
# --> 212         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     213         self.initialize()
#     214
#
# ~\Anaconda3\envs\recession\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#      62         hasconst = kwargs.pop('hasconst', None)
#      63         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 64                                       **kwargs)
#      65         self.k_constant = self.data.k_constant
#      66         self.exog = self.data.exog
#
# ~\Anaconda3\envs\recession\lib\site-packages\statsmodels\base\model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      85
#      86     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# ---> 87         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#      88         # kwargs arrays could have changed, easier to just attach here
#      89         for key in kwargs:
#
# ~\Anaconda3\envs\recession\lib\site-packages\statsmodels\base\data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     631     klass = handle_data_class_factory(endog, exog)
#     632     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 633                  **kwargs)
#
# ~\Anaconda3\envs\recession\lib\site-packages\statsmodels\base\data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      77
#      78         # this has side-effects, attaches k_constant and const_idx
# ---> 79         self._handle_constant(hasconst)
#      80         self._check_integrity()
#      81         self._cache = resettable_cache()
#
# ~\Anaconda3\envs\recession\lib\site-packages\statsmodels\base\data.py in _handle_constant(self, hasconst)
#     131             ptp_ = self.exog.ptp(axis=0)
#     132             if not np.isfinite(ptp_).all():
# --> 133                 raise MissingDataError('exog contains inf or nans')
#     134             const_idx = np.where(ptp_ == 0)[0].squeeze()
#     135             self.k_constant = const_idx.size
#
# MissingDataError: exog contains inf or nans

# %%
with open('../data/processed/stat_drop2.csv', 'w') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(stat_drop)

# %%
# start with complete dataset in ser_data2
print(ser_data2.shape)
# Out:
# (546, 34299)

# %%
n_drop = pd.read_csv('../data/processed/nber_drop.csv',header=None)

# %%
# drop nber recession dates that are after the fact
ser_data2.drop(n_drop.iloc[:,0], axis=1, errors='ignore', inplace=True)
ser_data2.shape
# Out:
# (546, 34255)

# %%
# save dataset with nber drop
ser_data2.to_csv('../data/processed/series_data_scaled2-nd-082919.csv')

# %%
delay_drop = pd.read_csv('../data/processed/delay_drop.csv')

# %%
# drop data series that are delayed by more than ~34 days
ser_data2.drop(delay_drop.columns, axis=1, inplace=True, errors='ignore')
ser_data2.shape
# Out:
# (546, 19019)

# %%
# save dataset with delay drop
ser_data2.to_csv('../data/processed/series_data_scaled2-nd-dd-082919.csv')

# %%
# drop data series that are non-stationary per adfuller test
ser_data2.drop(stat_drop, axis=1, inplace=True, errors='ignore')
ser_data2.shape
# Out:
# (546, 14260)

# %%
# save dataset with stat drop
ser_data2.to_csv('../data/processed/series_data_scaled2-nd-dd-sd-082919.csv')

# %%
ser_data2
# Out:
#             CES4000000007  COMPU1USA  CHEBSBUFT02STSAQ  \
# date
# 1969-01-01       0.982143   0.302537          0.787134
# 1969-02-01       0.946429   0.324008          0.787134
# 1969-03-01       0.946429   0.324008          0.909803
# 1969-04-01       0.928571   0.245934          0.909803
# 1969-05-01       0.946429   0.290826          0.909803
# 1969-06-01       0.910714   0.309694          0.960313
# 1969-07-01       0.928571   0.284320          0.960313
# 1969-08-01       0.928571   0.277163          0.960313
# 1969-09-01       0.928571   0.257645          1.000000
# 1969-10-01       0.910714   0.281067          1.000000
# 1969-11-01       0.910714   0.254392          1.000000
# 1969-12-01       0.928571   0.255042          0.895371
# 1970-01-01       0.910714   0.296682          0.895371
# 1970-02-01       0.892857   0.251789          0.895371
# 1970-10-01       0.857143   0.281067          0.779918
# 1970-11-01       0.857143   0.306441          0.779918
# 1970-12-01       0.839286   0.299935          0.642818
# 1971-01-01       0.821429   0.307742          0.642818
# 1971-02-01       0.839286   0.321405          0.642818
# 1971-03-01       0.821429   0.344177          0.629469
# 1971-04-01       0.839286   0.425504          0.629469
# 1971-05-01       0.803571   0.389720          0.629469
# 1971-06-01       0.839286   0.384515          0.543241
# 1971-07-01       0.767857   0.429408          0.543241
# 1971-08-01       0.839286   0.433962          0.543241
# 1971-09-01       0.839286   0.458035          0.468196
# 1971-10-01       0.839286   0.467144          0.468196
# 1971-11-01       0.839286   0.481457          0.468196
# 1971-12-01       0.875000   0.500976          0.426345
# 1972-01-01       0.857143   0.493819          0.426345
# ...                   ...        ...               ...
# 2017-02-01       0.160714   0.247235          0.558538
# 2017-03-01       0.142857   0.289525          0.631814
# 2017-04-01       0.196429   0.266753          0.631814
# 2017-05-01       0.178571   0.288224          0.631814
# 2017-06-01       0.196429   0.275862          0.630191
# 2017-07-01       0.214286   0.286272          0.630191
# 2017-08-01       0.214286   0.227716          0.630191
# 2017-09-01       0.196429   0.264802          0.659523
# 2017-10-01       0.214286   0.272609          0.659523
# 2017-11-01       0.250000   0.245934          0.659523
# 2017-12-01       0.232143   0.288874          0.653895
# 2018-01-01       0.196429   0.309694          0.653895
# 2018-02-01       0.214286   0.338972          0.653895
# 2018-03-01       0.232143   0.303188          0.721759
# 2018-04-01       0.196429   0.290176          0.721759
# 1971-02-01     1.000000     0.655370      0.426053        0.0
# 1971-03-01     0.499294     1.000000      0.342235        0.0
# 1971-04-01     0.311826     1.000000      0.480537        0.0
# 1971-05-01     0.043605     0.625932      0.273358        0.0
# 1971-06-01     0.211199     0.827747      0.373950        0.0
# 1971-07-01     0.032409     0.678479      0.300903        0.0
# 1971-08-01     0.186115     0.805857      0.264927        0.0
# 1971-09-01     0.174261     1.000000      0.302499        0.0
# 1971-10-01     0.259423     1.000000      0.301279        0.0
# 1971-11-01     0.309097     1.000000      0.309673        0.0
# 1971-12-01     0.128052     1.000000      0.222888        0.0
# 1972-01-01    -0.030981     0.652844      0.092325        0.0
# ...                 ...          ...           ...        ...
# 2017-02-01     0.011675     0.027740      0.009504        0.0
# 2017-03-01     0.007819     0.036799      0.011136        0.0
# 2017-04-01     0.004365     0.041942      0.017235        0.0
# 2017-05-01     0.009028     0.033833      0.010640        0.0
# 2017-06-01     0.011091     0.029598      0.014017        0.0
# 2017-07-01     0.003026     0.030617      0.011915        0.0
# 2017-08-01     0.003807     0.029637      0.006256        0.0
# 2017-09-01     0.022676     0.050777      0.026765        0.0
# 2017-10-01     0.026950     0.053217      0.027007        0.0
# 2017-11-01     0.035301     0.060868      0.027790        0.0
# 2017-12-01     0.017179     0.060005      0.029816        0.0
# 2018-01-01    -0.001167     0.033347      0.012432        0.0
# 2018-02-01    -0.001470     0.047083      0.013530        0.0
# 2018-03-01    -0.008868     0.042455      0.009862        0.0
# 2018-04-01     0.007908     0.036993      0.009940        0.0
# 2018-05-01     0.016919     0.055271      0.018679        0.0
# 2018-06-01     0.020245     0.051893      0.016673        0.0
# 2018-07-01     0.023587     0.058250      0.019958        0.0
# 2018-08-01     0.007151     0.058787      0.014220        0.0
# 2018-09-01    -0.000574     0.027979      0.007969        0.0
# 2018-10-01     0.003033     0.033604      0.016297        0.0
# 2018-11-01     0.006115     0.028939      0.012964        0.0
# 2018-12-01    -0.015324    -0.004869     -0.013348        0.0
# 2019-01-01    -0.013027     0.021331     -0.002425        0.0
# 2019-02-01    -0.020248     0.009590     -0.010172        0.0
# 2019-03-01     0.027187     0.031331      0.009768        0.0
# 2019-04-01     0.013814     0.027316      0.008273        0.0
# 2019-05-01     0.028812     0.021397      0.014707        0.0
# 2019-06-01     0.008715     0.019676      0.014763        0.0
# 2019-07-01     0.015046     0.018744      0.018027        0.0
#
# [546 rows x 6526 columns]

# %%
X = ser_data2.drop(['RECESSION'], axis=1)
X.shape
# Out:
# (546, 19463)

# %%
# get list of series that are highly correlated
corr_drop = []
idx = 0
for col in X.columns:
    idx += 1
    ser = X[col]
    for cols in X.columns[idx:]:
        corr = np.corrcoef(ser, X[cols])[0,1]
        if corr > 0.95:
            corr_drop.append(col)
            break
    print(idx, end='\r')
# Out:
# 19417

# %%
len(corr_drop)
# Out:
# 6997

# %%
with open('../data/raw/corr_drop.csv', 'w') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(corr_drop)
